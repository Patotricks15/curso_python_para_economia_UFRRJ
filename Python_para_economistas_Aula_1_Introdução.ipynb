# %% [markdown]
# <a href="https://colab.research.google.com/github/Patotricks15/curso_python_para_economia_UFRRJ/blob/main/Python_para_economistas_Aula_1_Introdu%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MINI-CURSO DE INTRODUÇÃO AO PYTHON PARA ECONOMISTAS
#
# ---
# Ministrador: [Patrick Gomes](https://www.linkedin.com/in/patotricks15/)

# %% [markdown]
# ![Real-Python-Write-For-Us_Watermarked.636fa20a1ee8.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Introdução
#
# * Textos
# * Operadores aritméticos
# * Tipos primitivos
# * Operadores lógicos

# %%
# !pip install currencies
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## Textos
#
# Com o Python conseguimos exibir frases e textos que gostaríamos. Para isso utilizaremos a função **print()**
#
# Como um primeiro exemplo, mostre o seu nome como resultado do código

# %%
print('Patrick')
# Out:
# Patrick

# %% [markdown]
# Uma maneira de guardar valores para exibí-los depois é salvando-os como uma **variável**.
#
# Agora guarde o seu nome numa variável chamada "nome"

# %%
nome = 'Patrick'

print(nome)
# Out:
# Patrick

# %% [markdown]
# Agora faça com outras variáveis:

# %%
nome = 'Patrick'
idade = 24
cidade = 'Seropédica'

print('Meu nome é', nome, 'minha idade é', idade, 'moro em', cidade)
# Out:
# Meu nome é Patrick minha idade é 24 moro em Seropédica

# %% [markdown]
# Agora vamos deixar a leitura e o código mais simples. Vamos utilizar o **print formatado**

# %%
nome = 'Patrick'
idade = 24
cidade = 'Seropédica'

print(f'Meu nome é {nome}, minha idade é {idade}, moro em {cidade}')
# Out:
# Meu nome é Patrick, minha idade é 24, moro em Seropédica

# %% [markdown]
# Agora nós vamos conhecer a função **input()**. Essa função serve para que a variável receba um valor que saia do seu **TECLADO**. Vamos lá:

# %%
nome = input('Digite seu nome: ')
idade = input('Digite sua idade: ')

print(f'Eu sou {nome} e tenho {idade} anos')
# Out:
# Digite seu nome: Patrick
# Digite sua idade: 24
# Eu sou Patrick e tenho 24 anos

# %% [markdown]
# **Concatenar** palavras para formar seu nome completo. Para isso, utilizaremos o operador +

# %%
nome = 'Patrick'
sobre = 'Gomes'

nome_completo = nome+' '+sobre
print(nome_completo)
# Out:
# Patrick Gomes

# %% [markdown]
# Agora vamos somar uns números??

# %%
num1 = input('Numero 1: ')
num2 = input('Numero 2: ')

soma = num1+num2

print('A soma da operação é', soma)
# Out:
# Numero 1: 10
# Numero 2: 2
# A soma da operação é 102

# %% [markdown]
# ## Tipos de Variáveis (ou tipos primitivos)
#
# Os 4 principais tipos de variáveis no Python são:
#
# **Int**: números inteiros (1, 2, 4, 1000, -358)
#
# **Float**: números reais, ou chamados de ponto flutuante (0.2, 0.004, 2.5, -7.8, 0.0, 3.0)
#
# **Str**: Strings, que são como "objetos". ("Python", "Patrick", "2", "3.0"). Estão **SEMPRE** acompanhados de aspas (simples ou duplas)
#
# **Bool**: Booleanos. São, basicamente verdadeiro/falso, mas como o Python usa o inglês, temos True/False.
#
# Vamos ver na prática como isso fucniona.

# %% [markdown]
# Para utilizar **inteiros**, basta criar a variável como tal, sem valores decimais

# %%
var_int = 4

# %% [markdown]
# Ao utilizar **Floats**, precisamos ter cuidado com uma detalhe. A vírgula, em Python, serve pra enumeração, e não para casas decimais.
#
# Para definir casas decimais, vamos utilizar o ponto `.`
#
# Para criar um float, basta associar à variável um número que possua casa decimal.

# %%
var_float = 4.0

# %% [markdown]
# **Strings** são nossa linguagem natural, utilizando caracteres e palavras.
#
# Para criar strings, precisamos colocar nosso conteúdo entre aspas, simples ou duplas.

# %%
var_str = '4.0'

# %% [markdown]
# É claro que você vai sempre criar as variáveis da forma desejada, e seguindo os padrões para não encontrar erros ou problemas no seu código.
#
# Entretanto, não é incomum encontrarmos, por exemplo, números que estão em formato string, e por isso, se comportarão como tal, não permitindo operações matemáticas, por exemplo.
#
# Para que possamos descobrir o tipo das nossas variáveis, temos a função `type`

# %%
var = 5
type(var)
# Out:
# int

# %% [markdown]
# Podemos ainda mudar o tipo de variável, veja como é simples:

# %%
numero = '4'

numero = float(numero)
type(numero)
# Out:
# float

# %% [markdown]
# ### Exercícios

# %%
# 1 - VERIFIQUE O TIPO DE CADA VARIÁVEL
a = 'Python'
b = 1.3
c = 3.0
d = 5

print(f'{a} --> {type(a)}\n{b} --> {type(b)}')
# Out:
# Python --> <class 'str'>
# 1.3 --> <class 'float'>

# %% [markdown]
# ## Operadores Aritméticos
#
# <center><img alt="Math" width="35%" src="https://image.freepik.com/free-psd/flat-lay-pi-sign-mathematics_23-2148458911.jpg"></center>
#
#
# Nesta aula, vou te mostrar quais são os operadores aritméticos do Python, além da sua ordem de precedência quando compondo uma expressão matemática.
#
# Os operadores aritméticos do Python são:
#
# * `+` Adição
# * `-` Subtração
# * `*` Multiplicação
# * `/` Divisão
# * `**` Exponenciação
# * `//` Divisão (resultado inteiro)
#
# Abaixo, podemos ver exemplos de uso desses operadores.

# %%
# adição
13 + 45 + 89 + 90
# Out:
# 237

# %%
# subtração
87 - 700
# Out:
# -613

# %%
# multiplicação
7 * 10
# Out:
# 70

# %%
# divisão
70 / 3
# Out:
# 23.333333333333332

# %%
# divisão (resultado inteiro)
70 // 3
# Out:
# 23

# %%
# resto da divisão
70 % 2
# Out:
# 0

# %%
# exponenciação
7 ** 2
# Out:
# 49

# %% [markdown]
# ## Ordem de precedência
#
# Se já faz um tempo desde o seu último contato com a matemática, vale a pena relembrarmos a ordem correta das operações matemáticas.
#
# $$
# \begin{aligned}
# x & = 3 + 10 * 3 \\
# x & = 3 + (10 * 3) \\
# x & = 3 + 30 \\
# x & = 33
# \end{aligned}
# $$
#
# Lembre-se que a ordem das operações matemáticas é:
#
# * 1º Parêntesis;
# * 2º Expoentes;
# * 3º Multiplicações e Divisões; (da esquerda para a direita)
# * 4º Somas e Subtrações. (da esquerda para a direita)
#
# Vamos ver como isso funciona na prática com Python.

# %%
# Playground
3 + 10*3
# Out:
# 33

# %% [markdown]
# Mesmo acrescentando um pouquinho mais de complexidade, o Python consegue lidar com extrema facilidade, cabendo a nós termos atenção às operações realizadas.
#
# $$
# \begin{aligned}
# x & = 5 + 9 - 2^2 + \frac{9}{3} \\
# x & = 5 + 9 - 4 + \frac{9}{3} \\
# x & = 5 + 9 - 4 + 3 \\
# x & = 14 - 4 + 3 \\
# x & = 10 + 3 \\
# x & = 13 \\
# \end{aligned}
# $$

# %%
# resolução da equação acima usando Python
5 + 9 - 2**2 + 9/3
# Out:
# 13.0

# %%
5 + 9 - (2**2) + (9/3)
# Out:
# 13.0

# %% [markdown]
# Expressões maiores podem confundir, então o segredo é anotar a correta ordem de execução das operações matemáticas:
#
# 1. Parêntesis
# 2. Expoentes
# 3. Multiplicações e Divisões (esquerda para a direita)
# 4. Somas e subtrações (esquerda para a direita)
#
# #### Exemplo 1
#
# Calcula a média simples das notas das 3 provas de matemática
# * Nota 1 = 8,5
# * Nota 2 = 9,2
# * Nota 3 = 7,5

# %%
# resposta

nota1 = 8.5
nota2 = 9.2
nota3 = 10

media = (nota1 + nota2 + nota3) / 3

print(media)
# Out:
# 9.233333333333333

# %% [markdown]
# ### Exercícios

# %%
# 1 - ANTECESSOR  E SUCESSOR

numero = 6

sucessor =  numero + 1
antecessor = numero - 1

print(f"O antecessor é {antecessor} e o sucessor é {sucessor}")
# Out:
# O antecessor é 5 e o sucessor é 7

# %%
# 2 - DOBRO E RAÍZ QUADRADA
numero = 4

# %%
# 3 - MÉDIA PONDERADA
nota1 = 10
nota2 = 3
nota3 = 2

peso1 = 2
peso2 = 3
peso3 = 5

# %% [markdown]
# 4 - Calcular elasticidade

# %% [markdown]
# ![fórmula-da-elasticidade-300x144.jpg](data:image/jpeg;base64,...)

# %%
p0 = 10 # preço inicial
p1 = 5 # preço final

q0 = 3 # quantidade inicial
q1 = 7 # quantidade final

var_qtd = (q1 - q0) / q0
var_p = (p1 - p0) / p0

elasticidade = var_qtd / var_p

modulo_elasticidade = abs(elasticidade)

print(modulo_elasticidade)
# Out:
# 2.6666666666666665

# %% [markdown]
# 5 - Calcular taxa de juros simples
#
# J = C.i.t

# %%
p = # valor principal
i =  # taxa de juros ao ano
t = # tempo em anos

# %% [markdown]
# # Operadores lógicos

# %% [markdown]
# Igual ==
#
# Diferente !=
#
# Maior que >
#
# Menor que <
#
# Menor ou igual <=
#
# Maior ou igual >=

# %%
n1 = 4
n2 = 5

print(n1 == n2)
# Out:
# False

# %%
print(n1 > n2)
print(n1 < n2)
# Out:
# False
# True

# %%
n1 < n2
# Out:
# True

# %%
n1 != n2
# Out:
# True

# %%
n1 <= n2
# Out:
# True

# %%
n1 >= n2
# Out:
# False

# %% [markdown]
# #Bônus
# ---
# O que é uma biblioteca python?
# "A Biblioteca Padrão do Python é uma coleção de módulos de script acessíveis a um programa Python para simplificar o processo de programação e remover a necessidade de reescrever os comandos mais usados."
#
# Ou seja, uma biblioteca é um conjunto de funcionalidades para facilitar a implementação de uma tarefa. Existem bibliotecas de matemática, criação de sites, jogos, machine learning, geociências, integração com excel, e MUITO MUITO MAIS!!
#
# Bibliotecas que aprenderemos hoje:
# * **math**: uma biblioteca voltada para funções básicas da matemática
# * **random**: uma biblioteca que gera valores pseudo-aleatórios

# %%
import random, math

valor_inicial_aleatorio = random.randint(0,10)
print(valor_inicial_aleatorio)
juros = valor_inicial_aleatorio * 0.03 * 2 # cálculo do juros
print(juros)
# Out:
# 10
# 0.6

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %% [markdown]
# ## Desafio
#
# Para consolidar o entendimento vamos resolver um desafio. Nesse desafio vocês exercitarão: operadores matemáticos
#
# * Conversor de moedas (BRL -> US) + o tipo de variável que retorna

# %% [markdown]
# # RESUMÃO
#
# * Funções que aprendemos:
#
# print() --> serve para mostrar o resultado
#
# input() --> pede um valor a partir do seu teclado
#
# type() --> verifica o tipo de variável
#
# * Tipos de variáveis:
#
# int --> inteiros
#
# float --> reais
#
# str --> textos (strings)
#
# bool --> verdadeiro x falso (booleanos)
#
# * Operadores matemáticos:
#
# Adição -> ``+``
#
# Subtração -> ``-``
#
# Multiplicação -> ``*``
#
# Divisão -> ``/``
#
# * Operadores lógicos:
#
# Igual -> ``==``
#
# Diferente -> ``!=``
#
# Maior que -> ``>``
#
# Maior ou igual que -> ``>=``
#
# Menor que -> ``<``
#
# Menor ou igual que -> ``<=``
